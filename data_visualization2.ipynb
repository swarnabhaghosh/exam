# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Q1.

# %% [markdown]
# Take the iris dataset as input and plot the box-plot for the column " PetalLengthCm", for the column " PetalLengthCm" grouped by Species and multiple box-plots for each column.

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# matplotlib
plt.boxplot(iris["petal_length"])
plt.show()

# %%
# pandas
iris.boxplot("petal_length", "species")
plt.show()

# %%
# seaborn
sns.boxplot(x = "petal_length", y = "species", data = iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %% [markdown]
# ### Q2.

# %% [markdown]
# What is Histogram? Write a python code using matplotlib library to illustrate histogram.

# %% [markdown]
# A histogram is a visualization that shows the prevalence of numerical data over a distribution. The horizontal axis is a particular value, and the vertical axis displays how many times that value was observed in the data set.
#
# One key concept that you must understand when working with histograms is the idea of bins - how many parts the total range of the data set is divided into. Changing the number of bins in a histogram does not change the data set. It only changes the appearance of the data in the histogram.

# %%
plt.hist(data = iris, x = "petal_length", color = "teal", bins = 20)
# Out:
# (array([ 4., 33., 11.,  2.,  0.,  0.,  1.,  2.,  3.,  5., 12., 14., 12.,
#         17.,  6., 12.,  7.,  4.,  2.,  3.]),
#  array([1.   , 1.295, 1.59 , 1.885, 2.18 , 2.475, 2.77 , 3.065, 3.36 ,
#         3.655, 3.95 , 4.245, 4.54 , 4.835, 5.13 , 5.425, 5.72 , 6.015,
#         6.31 , 6.605, 6.9  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
#  ### Q3.

# %% [markdown]
# Plot the Scatter Plot of data points of a single dataset, multiple datasets and on iris dataset.

# %%
x =[5, 7, 8, 7, 2, 17, 2, 9,4, 11, 12, 9, 6]  
y =[99, 86, 87, 88, 100, 86,103, 87, 94, 78, 77, 85, 86]

# %%
plt.scatter(x, y)
plt.show()

# %%
# dataset-1 
x1 = [89, 43, 36, 36, 95, 10, 66, 34, 38, 20] 
y1 = [21, 46, 3, 35, 67, 95, 53, 72, 58, 10] 

# dataset2 
x2 = [26, 29, 48, 64, 6, 5, 36, 66, 72, 40] 
y2 = [26, 34, 90, 33, 38, 20, 56, 2, 47, 15]

# %%
plt.scatter(x1, y1)
plt.scatter(x2, y2)

# %%
plt.scatter(x1, y1, marker = 's')
plt.scatter(x2, y2, marker = '^')
plt.plot()
# Out:
# []

# %%
sns.set_style('whitegrid') 
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
plt.plot()
# Out:
# []

# %% [markdown]
# ### Q4.

# %% [markdown]
# Save the figure generated in Q-3 in a pdf file.

# %%
sns.set_style('whitegrid') 
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
plt.plot() 
plt.savefig("C:/Users/USER/Desktop/Swarnabha-CSE1-2023-036/image/assg2Q4.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# ### Q5.

# %% [markdown]
# Generate 10 data points. Plot scatter plot on the points and save the generated figure in a pdf file.

# %%
data = {
    'column1' : [i for i in range(10)],
    'column2' : [i*i for i in range(10)]
}
data = pd.DataFrame(data)
data
# Out:
#    column1  column2
# 0        0        0
# 1        1        1
# 2        2        4
# 3        3        9
# 4        4       16
# 5        5       25
# 6        6       36
# 7        7       49
# 8        8       64
# 9        9       81

# %%
plt.scatter(x = 'column1', y = 'column2', data = data)
plt.savefig("C:/Users/USER/Desktop/Swarnabha-CSE1-2023-036/image/assg2Q5.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# ### Q6.

# %% [markdown]
# Write a python code to show the use of Marker and styles in charts.

# %%
x=[1,2,6] 
y=[4,5,6] 
#plt.plot(x,y,marker=",")#pixel 
#plt.plot(x,y,marker="*")#star 
#plt.plot(x,y,marker="o")#circle 
#plt.plot(x,y,marker=".")#point 
#plt.plot(x,y,marker="s")#Square 
#plt.plot(x,y,marker="D")#Diamond 
#plt.plot(x,y,marker="p")#Pentagon 
#plt.plot(x,y,marker="H")#Hexagon 
#plt.plot(x,y,marker="v")#Triangle Down 
#plt.plot(x,y,marker="^")#Triangle up 
# plt.plot(x,y,marker="<")#Triangle Left 
plt.plot(x,y,marker=">")#Triangle Right
plt.show()

# %%
plt.plot(x,y,marker="o",ms=10)#circle

# %%
#plt.plot(x,y,"o:r")# : for dotted line 
#plt.plot(x,y,"o:b")#: for dotted line 
#plt.plot(x,y,"o-b")#: for solid line 
#plt.plot(x,y,"o--b")#: for dashed line 
plt.plot(x,y,"o-.b")#: for Dashed/dotted line
